# %% [markdown]
# #Problem 1
# Take a string from the user and print it in the reverse order using stack
# data structure. Also prints the unicode of each character
#
# Input:
# W A T E R M E L O N
#
# Output:
# N O L E M R E T A W
#
# Hint: Use the property of stack to reverse the string

# %%
class Stack:
    top = 0
    stack_size = 0
    stack = []

    def __init__(self, size):
        self.stack_size = size
        self.stack = [0] * size

    def stack_is_full(self):
        if self.top == self.stack_size:
            return True
        else:
            return False

    def push(self, value):
        if self.stack_is_full():
            print("Stack is full")
        else:
            self.stack[self.top] = value
            self.top = self.top + 1

    def stack_is_empty(self):
        if self.top == 0:
            return True
        else:
            return False

    def peak(self):
        if self.stack_is_empty():
            print("Stack is empty")
            return 0
        else:
            return self.stack[self.top - 1]

    def pop(self):
        if self.stack_is_empty():
            print("Stack is empty")
        else:
            self.stack[self.top - 1] = 0
            self.top = self.top - 1

def reverse(string):
    n = len(string)
    s = Stack(n)
    output = ""

    for i in range(n):
        s.push(string[i])

    while not s.stack_is_empty():
        output = output + s.peak()

        s.pop()

    return output

string = input("Enter a string : ")
string = reverse(string)
print("Reversed string is : "  + string)
# Out:
# Enter a string : W A T E R M E L O N
# Reversed string is : N O L E M R E T A W

# %% [markdown]
# #Problem 2.
#  Given a string of brackets, determine whether each sequence of brackets is
# balanced. If a string is balanced, print True on a new line; otherwise, print False on
# a new line.
# Input : Output
#
# ()  True
#
# {} True
#
# [] True
#
# {[]} True
#
# {([)]} False
#
# (() False
#
# {[(]} False

# %%
class Stack:
    top = 0
    stack_size = 0
    stack = []

    def __init__(self, size):
        self.stack_size = size
        self.stack = [0] * size

    def stack_is_full(self):
        if self.top == self.stack_size:
            return True
        else:
            return False

    def push(self, value):
        if self.stack_is_full():
            print("Stack is full")
        else:
            self.stack[self.top] = value
            self.top = self.top + 1

    def stack_is_empty(self):
        if self.top == 0:
            return True
        else:
            return False

    def peak(self):
        if self.stack_is_empty():
            print("Stack is empty")
            return 0
        else:
            return self.stack[self.top - 1]


    def pop(self):
        if self.stack_is_empty():
            print("Stack is empty")
        else:
            self.stack[self.top - 1] = 0
            self.top = self.top - 1

    def find_Balance(each_bracket):
        stack = []
        for char in each_bracket:
            if char in ["(", "{", "["]:
                stack.append(char)
            else:
                if not stack:
                    return False
                curr_char = stack.pop()
                if curr_char == '(':
                    if char != ")":
                        return False
                if curr_char == '{':
                    if char != "}":
                        return False
                if curr_char == '[':
                    if char != "]":
                        return False

        if stack:
            return False
        return True


    m = input("Bracket: ")

    if find_Balance(m):
        print("True")
    else:
        print("False")
# Out:
# Bracket: {[]}
# True

# %% [markdown]
# #Problem 3.
# Suppose, you have a stack class. You have 5 utility functions: isempty(), push(), pop(),
# peek() and size().  Write a program keepLargestOnTop(stack) in a way that the largest
# value in that stack would be in the TOP position always. Return the stack.
# Hints: You should use a helpingStack and its functions helpingStackPush(),
# helpingStackPop(), helpingStackisEmpty(), helpingStacksize(). Assume: these are
# already implemented. You need to use them properly.
# Current stack
#
#
# 23
#
# 53
#
# 56
#
# 19
#
# 44
#
# 22
#
# 99
#
#
# 44
#
# TOP
#
# After your Program keepLargestOnTop(stack): Stack looks like below:
#
# 23
#
# 53
#
# 56
#
# 19
#
# 44
#
# 22
#
# 44
#
# 99
#
# TOP

# %%
class Stack:
    top = 0
    stack_size = 0
    stack = []

    def __init__(self, size):
        self.stack_size = size
        self.stack = [0] * size

    def is_full(self):
        if self.top == self.stack_size:
            return True
        else:
            return False

    def push(self, value):
        if self.is_full():
            print("Stack is full")
        else:
            self.stack[self.top] = value
            self.top = self.top + 1

    def is_empty(self):
        if self.top == 0:
            return True
        else:
            return False

    def peak(self):
        if self.is_empty():
            print("Stack is empty")
        else:
            return self.stack[self.top - 1]

    def pop(self):
        if self.is_empty():
            print("Stack is empty")
        else:
            self.stack[self.top - 1] = 0
            self.top = self.top - 1


first = Stack(8)

first.push(23)
first.push(53)
first.push(56)
first.push(19)
first.push(44)
first.push(22)
first.push(99)
first.push(44)
print(first.stack)

second = Stack(8)

highest = -999999999

while not first.is_empty():
  peak = first.peak()
  first.pop()
  if peak >highest:
    highest = peak
  second.push(peak)


while not second.is_empty():
  peak = second.peak()
  second.pop()
  if peak != highest:
    first.push(peak)

first.push(highest)
print(first.stack)
# Out:
# [23, 53, 56, 19, 44, 22, 99, 44]
# [23, 53, 56, 19, 44, 22, 44, 99]

# %% [markdown]
# #Problem 4.
#  Given two stacks with integer values, balance the sum of integer values present in each of
# the stack by adding a new element in any of the stack. For example, if stack A contains 1,
# 5, 11 and 4 and stack B contains 4 ,32,- 1 and 1 then by adding 15 in stack A will balance
# the sum of values of both the stacks.
# Input:
# 1 4
# 5 32
#
# 11
# 1
# 4 -1
# Stack A Stack B
# Output:
# 1 4
# 5 32
#
# 11 1
# 4 -1
# Stack A 15
# Stack B

# %%
class Stack:
    top = 0
    stack_size = 0
    stack = []

    def __init__(self, size):
        self.stack_size = size
        self.stack = [0] * size

    def is_full(self):
        if self.top == self.stack_size:
            return True
        else:
            return False

    def push(self, value):
        if self.is_full():
            print("Stack is full")
        else:
            self.stack[self.top] = value
            self.top = self.top + 1

    def is_empty(self):
        if self.top == 0:
            return True
        else:
            return False

    def peak(self):
        if self.is_empty():
            print("Stack is empty")
        else:
            return self.stack[self.top - 1]

    def pop(self):
        if self.is_empty():
            print("Stack is empty")
        else:
            self.stack[self.top - 1] = 0
            self.top = self.top - 1


elements = int(input("How many elements in the stack?: "))
stackA = Stack(elements + 1)
stackB = Stack(elements + 1)

total_A = 0
total_B = 0

for i in range(elements):
    element_A = int(input("Enter element for stack A: "))
    element_B = int(input("Enter element for stack B: "))

    total_A = total_A + element_A
    total_B = total_B + element_B

    stackA.push(element_A)
    stackB.push(element_B)


print("Before balancing: ")
print("Stack A:", stackA.stack)
print("Stack B:", stackB.stack)

sum_of_ellements = abs(total_B - total_A)

if total_A < total_B:
    stackA.push(sum_of_ellements)
else:
    stackB.push(sum_of_ellements)


print("After balancing: ")
print("Stack A:", stackA.stack)
print("Stack B:", stackB.stack)
# Out:
# How many elements in the stack?: 4
# Enter element for stack A: 1
# Enter element for stack B: 4
# Enter element for stack A: 5
# Enter element for stack B: 32
# Enter element for stack A: 11
# Enter element for stack B: 1
# Enter element for stack A: 4
# Enter element for stack B: -1
# Before balancing:
# Stack A: [1, 5, 11, 4, 0]
# Stack B: [4, 32, 1, -1, 0]
# After balancing:
# Stack A: [1, 5, 11, 4, 15]
# Stack B: [4, 32, 1, -1, 0]

# %% [markdown]
# #Problem 5.
#
# We have a stack class and have 5 utility functions: isempty(), push(), pop(), peek() and size().  The stack is maintaining the ascending order always. Now, you would need to insert a new value into this stack using a pushStack(value) function. Write the pushStack(value) utility function for the stack class so that the function always maintains the ascending order in the stack.

# %%
class Stack:
    top = 0
    stack_size = 0
    stack = []

    def __init__(self, size):
        self.stack_size = size
        self.stack = [0] * size

    def is_full(self):
        if self.top == self.stack_size:
            return True
        else:
            return False

    def push(self, value):
        if self.is_full():
            print("Stack is full")
        else:
            self.stack[self.top] = value
            self.top = self.top + 1

    def is_empty(self):
        if self.top == 0:
            return True
        else:
            return False

    def peak(self):
        if self.is_empty():
            print("Stack is empty")
            return 0
        else:
            return self.stack[self.top - 1]

    def pop(self):
        if self.is_empty():
            print("Stack is empty")
        else:
            self.stack[self.top - 1] = 0
            self.top = self.top - 1

    def pushStack(self, value):
        if self.is_full():
            print("Stack is full")
        else:
            if self.is_empty():
                self.push(value)
            else:
                temp_stack = Stack(self.stack_size)

                while not ((self.is_empty()) or (value > self.peak())):
                    top = self.peak()
                    temp_stack.push(top)
                    self.pop()

                self.push(value)

                while not temp_stack.is_empty():
                    top = temp_stack.peak()
                    self.push(top)
                    temp_stack.pop()


stack1 = Stack(5)

stack1.pushStack(160)
stack1.pushStack(67)
stack1.pushStack(456)
stack1.pushStack(259)
stack1.pushStack(120)

print(stack1.stack)
# Out:
# [67, 120, 160, 259, 456]

# %% [markdown]
# #Problem 6.
# Program a simple text editor using Stack. The user will input a complete sentence. You have to put this string into a character stack. When the user selects the option to undo, a word from the stack will be deleted. By selecting undo again, another word from the stack will be removed and so on.

# %%
class Stack:
    top = 0
    stack_size = 0
    stack = []

    def __init__(self, size):
        self.stack_size = size
        self.stack = [0] * size

    def is_full(self):
        if self.top == self.stack_size:
            return True
        else:
            return False

    def push(self, value):
        if self.is_full():
            print("Stack is full")
        else:
            self.stack[self.top] = value
            self.top = self.top + 1

    def is_empty(self):
        if self.top == 0:
            return True
        else:
            return False

    def peak(self):
        if self.is_empty():
            print("Stack is empty")
            return 0
        else:
            return self.stack[self.top - 1]


    def pop(self):
        if self.is_empty():
            print("Stack is empty")
        else:
            self.stack[self.top - 1] = 0
            self.top = self.top - 1

    def pushStack(self, value):
        if self.is_full():
            print("Stack is full")
        else:
            if self.is_empty():
                self.push(value)
            else:
                temp_stack = Stack(self.stack_size)

                while not ((self.is_empty()) or (value > self.peak())):
                    top = self.peak()
                    temp_stack.push(top)
                    self.pop()

                self.push(value)

                while not temp_stack.is_empty():
                    top = temp_stack.peak()
                    self.push(top)
                    temp_stack.pop()


stack = Stack(100)
stack2 = Stack(100)
while True:
    print("1. Input Text")
    print("2. Undo Text")
    print("3. Display Text")
    print("4. Exit")

    option = input("Enter your choice: ")

    if option == "1":
        string = input("Enter a string: ")
        stack.push(string)
    elif option == "2":
        stack.pop()
    elif option == "3":
        while not stack.is_empty():
            stack2.push(stack.peak())
            stack.pop()

        while not stack2.is_empty():
            print(stack2.peak(), end='')
            stack.push(stack2.peak())
            stack2.pop()

        print()
        print()

    elif option == "4":
        break
    else:
        print("Invalid input")


print("This program is end")
# Out:
# 1. Input Text
# 2. Undo Text
# 3. Display Text
# 4. Exit
# Enter your choice: 1
# Enter a string: Aysa
# 1. Input Text
# 2. Undo Text
# 3. Display Text
# 4. Exit
# Enter your choice: 3
# Aysa
#
# 1. Input Text
# 2. Undo Text
# 3. Display Text
# 4. Exit
# Enter your choice: 1
# Enter a string:  Siddika
# 1. Input Text
# 2. Undo Text
# 3. Display Text
# 4. Exit
# Enter your choice: 3
# Aysa Siddika
#
# 1. Input Text
# 2. Undo Text
# 3. Display Text
# 4. Exit
# Enter your choice: 2
# 1. Input Text
# 2. Undo Text
# 3. Display Text
# 4. Exit
# Enter your choice: 3
# Aysa
#
# 1. Input Text
# 2. Undo Text
# 3. Display Text
# 4. Exit
# Enter your choice: 1
# Enter a string:  Meem
# 1. Input Text
# 2. Undo Text
# 3. Display Text
# 4. Exit
# Enter your choice: 3
# Aysa Meem
#
# 1. Input Text
# 2. Undo Text
# 3. Display Text
# 4. Exit
# Enter your choice: 4
# This program is end

# %% [markdown]
# #problem 7.
# Reverse the first ‘k’ elements of a queue, push it back into the queue. For example, if the
# queue has members 10, 20, 30, 40 , 50 , 60 , 70, 80, 90 and first 5 numbers are asked to be
# reversed then the result will be 60, 70, 80, 90, 50, 40, 30, 20, 10.
#
# Input:
#
# 10 20 30 40 50 60 70 80 90
#
# Output:
#
# 60 70 80 90 50 40 30 20 10

# %%
class Queue:
    def __init__(self):
        self.queue = []

    def size(self):
        return len(self.queue)

    def is_empty(self):
        if self.size() == 0:
            return True
        else:
            return False

    def enqueue(self, data):
        self.queue.append(data)


    def dequeue(self):
        if self.is_empty():
            print("Queue is empty")
        else:
            self.queue.pop(0)

    def front(self):
        if self.is_empty():
            print("Queue is empty")
        else:
            return self.queue[0]

    def back(self):
        if self.is_empty():
            print("Queue is empty")
        else:
            return self.queue[-1]


class Stack:
    def __init__(self):
        self.stack = []

    def size(self):
        return len(self.stack)

    def is_empty(self):
        if self.size() == 0:
            return True
        else:
            return False

    def push(self, data):
        self.stack.append(data)


    def pop(self):
        if self.is_empty():
            print("Stack is empty")
        else:
            self.stack.pop(-1)

    def peak(self):
        if self.is_empty():
            print("Stack is empty")
        else:
            return self.stack[-1]


num_elements = int(input("How many elements in the queue: "))

q = Queue()
s = Stack()
for i in range(num_elements):
    element = int(input("Enter element: "))
    q.enqueue(element)

print("Before reverse:", q.queue)

while True:
    num = int(input("How many numbers to reverse?: "))

    if num <= q.size():
        break
    else:
        print("Cannot reverse more than the size of the queue")


for i in range(num):
    s.push(q.front())
    q.dequeue()

while not s.is_empty():
    q.enqueue(s.peak())
    s.pop()

print("After Reverse:", q.queue)
# Out:
# How many elements in the queue: 9
# Enter element: 10
# Enter element: 20
# Enter element: 30
# Enter element: 40
# Enter element: 50
# Enter element: 60
# Enter element: 70
# Enter element: 80
# Enter element: 90
# Before reverse: [10, 20, 30, 40, 50, 60, 70, 80, 90]
# How many numbers to reverse?: 5
# After Reverse: [60, 70, 80, 90, 50, 40, 30, 20, 10]

# %% [markdown]
# #Problem 8.
# You have two volunteers who are collecting donations from the members of a community.
# Suppose each of the members has a member id and they are lined up in ascending order. To
# keep the number of people balanced, volunteer A is collecting donations from members
# whose ids are divisible by 2 and volunteer B is collecting donations from members whose
# ids are not divisible by 2. Write a program which uses two queues, such that if the even
# number member id is given, it will assign that member to volunteer A, otherwise, the
# member will go to volunteer B.
#
# Input:
# 2 4 7 10 1 9 11
#
# Output:
# 2 4 10
#
# Queue A
#
# 7 1 9 11
#
# Queue B

# %%
class Queue:
    def __init__(self):
        self.queue = []

    def size(self):
        return len(self.queue)

    def is_empty(self):
        if self.size() == 0:
            return True
        else:
            return False

    def enqueue(self, data):
        self.queue.append(data)

    def dequeue(self):
        if self.is_empty():
            print("Queue is empty")
        else:
            self.queue.pop(0)

    def front(self):
        if self.is_empty():
            print("Queue is empty")
        else:
            return self.queue[0]

    def back(self):
        if self.is_empty():
            print("Queue is empty")
        else:
            return self.queue[-1]


num = int(input("How many members to collecting donations from community?: "))

volunteer_A = Queue()
volunteer_B = Queue()

for i in range(num):
    member_id = int(input("Enter member ID: "))

    if member_id % 2 == 0:  # even
        volunteer_A.enqueue(member_id)
    else:
      volunteer_B.enqueue(member_id)


print("Volunteer A:",volunteer_A.queue)
print("Volunteer B:", volunteer_B.queue)
# Out:
# How many members to collecting donations from community?: 7
# Enter member ID: 2
# Enter member ID: 4
# Enter member ID: 7
# Enter member ID: 10
# Enter member ID: 1
# Enter member ID: 9
# Enter member ID: 11
# Volunteer A: [2, 4, 10]
# Volunteer B: [7, 1, 9, 11]

# %% [markdown]
# #Problem 9.
#  Given a number n, write a function that generates and prints all binary numbers with decimal values from 1 to n. You need to use a queue for that
#
# Input: 5
#
# Output: 0
# 01
#
# 10
#
# 11
#
# 100
#
# 101
#
#
# Input: 3
#
# Output:
#
# 0
#
# 01
#
# 10
#
# 11
#
# Input: 1
#
# Output:
#
# 0
#
# 01

# %%
class Queue:
    def __init__(self):
        self.queue = []

    def size(self):
        return len(self.queue)

    def is_empty(self):
        if self.size() == 0:
            return True
        else:
            return False

    def enqueue(self, data):
        self.queue.append(data)


    def dequeue(self):
        if self.is_empty():
            print("Queue is empty")
        else:
            self.queue.pop(0)

    def front(self):
        if self.is_empty():
            print("Queue is empty")
        else:
            return self.queue[0]

    def back(self):
        if self.is_empty():
            print("Queue is empty")
        else:
            return self.queue[-1]


n = int(input("Enter number to convert binary: "))
q = Queue()

for i in range(n + 1):
    bin_num = str(bin(i))

    for j in bin_num:
        q.enqueue(j)

    q.dequeue()
    q.dequeue()

    output = ""
    while not q.is_empty():
        output = output + q.front()
        q.dequeue()

    print(output)
# Out:
# Enter number to convert binary: 5
# 0
# 1
# 10
# 11
# 100
# 101

# %% [markdown]
# # ***Name : Mst. Aysa Siddika Meem***.
# * ID : 2220281
#
# * Section : 10
#
# * Course: CSE211
#
# * Assesment : 1

# %% [markdown]
# #Problem 1.
# Write a function getAverage(Head) that will take head of a singly linked list and return the
# average.
# Head
# ``` bash
# 5 -> 6 -> 7 -> 8 -> -> NULL
# ```
# Here the call getAverage(Head) will return 6.5

# %%
class Node :
  def __init__ (self, data):
    self.data = data
    self.next = None

class Singly_Link_list:
  def __init__ (self):
    self.head = None
    self.size = 0

  def append(self,new_data):
    new_node = Node(new_data)
    if self.head is None:
      self.head = new_node
    else:
      current = self.head
      while current.next is not None:
        current = current.next
      current.next = new_node
    self.size +=1

  def print_all(self):
    current = self.head
    while current != None:
      print(current.data, end = "->")
      current = current.next
    print()


  def search(self, data):
    current = self.head
    while current is not None:
      if current.data == data:
        return True
      current = current.next
    return False

  def delete(self, data):
        if self.head is None:
            print("List is empty")
            return
        else:
            current = self.head
            previous = None
            while current != None:
                if current.data == data:
                    if previous is None:
                        self.head = self.head.next
                    else:
                        previous.next = current.next
                    self.size -= 1
                    return
                previous = current
                current = current.next


def getAverage(Head):
  if Head==None:
    print("list is empty")
  else:
    sum=0
    avg=0
    current=Head
    while current!=None:
      sum+=current.data
      current=current.next
    avg=sum/sl1.size
  print(f"Average: {avg}")


sl1=Singly_Link_list()
sl1.append(5)
sl1.append(6)
sl1.append(7)
sl1.append(8)
sl1.print_all()

getAverage(sl1.head)
# Out:
# 5->6->7->8->
# Average: 6.5

# %% [markdown]
# #Problem 2.
# Write a function numOfOccurrences(Head, value) that will take Head of a singly linked list and
# return the number of occurrences of the value in the list.

# %%
class Node :
  def __init__ (self, data):
    self.data = data
    self.next = None

class Singly_Link_list:
  def __init__ (self):
    self.head = None
    self.size = 0

  def append(self,new_data):
    new_node = Node(new_data)
    if self.head is None:
      self.head = new_node
    else:
      current = self.head
      while current.next is not None:
        current = current.next
      current.next = new_node
    self.size +=1

  def print_all(self):
    current = self.head
    while current != None:
      print(current.data, end = "->")
      current = current.next
    print()


  def search(self, data):
    current = self.head
    while current is not None:
      if current.data == data:
        return True
      current = current.next
    return False

  def delete(self, data):
        if self.head is None:
            print("List is empty")
            return
        else:
            current = self.head
            previous = None
            while current != None:
                if current.data == data:
                    if previous is None:
                        self.head = self.head.next
                    else:
                        previous.next = current.next
                    self.size -= 1
                    return
                previous = current
                current = current.next

def numOfOccurrences(head, value):
  if head is None:
    return 0
  else:
    current = head.head
    count = 0
    while current is not None:
      if current.data == value:
        count += 1
      current = current.next
    return count

given_list = [8, 3, 7, 8, 9, 0 , 1, 3, 9, 8, 1]

myList = Singly_Link_list()

for i in range(len(given_list)):
  myList.append(given_list[i])

myList.print_all()


numOfOccurrences(myList, 0)
# Out:
# 8->3->7->8->9->0->1->3->9->8->1->
# 1

# %% [markdown]
# #Problem 3.
# You’re given the pointer to the head nodes of two singly linked lists. Compare the
# data in the nodes of the linked lists to check if they are equal. The lists are equal only
# if they have the same number of nodes and corresponding nodes contain the same
# data.
# ```bash
# Figure: List A
#
# 7->6->10->11->NILL
# ```
# ``` bash
# Figure: List B
#
# 7->6->10->11->NULL
# ```
# ``` bash
# Figure: List C
#
# 7->16->10->11->NULL
# ```
# For example a function call to equalNode(A,B) will return true, equalNode(A,A) will return
# true, equalNode(A,C) will return false, equalNode(A,D) will return false.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None
        self.size = 0

    def append(self, new_data):
        new_node = Node(new_data)
        if self.head is None:
            self.head = new_node
        else:
            current = self.head
            while current.next is not None:
                current = current.next
            current.next = new_node
        self.size += 1

    def print_all(self):
        current = self.head
        while current is not None:
            print(current.data, end='->')
            current = current.next
        print()

    def search(self, data):
        current = self.head
        while current is not None:
            if current.data == data:
                return True
            current = current.next
        return False

def equal_lists(head1, head2):
    current1 = head1
    current2 = head2
    while current1 is not None and current2 is not None:
        if current1.data != current2.data:
            return False
        current1 = current1.next
        current2 = current2.next
    if current1 is None and current2 is None:
        return True
    else:
        return False


listA = SinglyLinkedList()
listA.append(7)
listA.append(6)
listA.append(10)
listA.append(11)


listB = SinglyLinkedList()
listB.append(7)
listB.append(6)
listB.append(10)
listB.append(11)


listC = SinglyLinkedList()
listC.append(7)
listC.append(16)
listC.append(10)
listC.append(11)


print(equal_lists(listA.head, listB.head))
print(equal_lists(listA.head, listA.head))
print(equal_lists(listA.head, listC.head))
# Out:
# True
# True
# False

# %% [markdown]
# #Problem 4.
#  Assume, Head is the head-node of a singly linked list (sll). Write a utility function
# addNodeBeforeValue (self, givenValue, newValue) to insert a new value in this sll just
# before the given value.
# ```bash
# 3->6->7->10->NULL
# ```
# a. If the given value is found in the sll, insert the new value just before the given value.
#
#
# b. If the given value is not found, don’t add the node. Just print “Not found”

# %%
class Node:
  def __init__(self):
    self.data = 0
    self.next = None

class SinglyLinkedList:
  def __init__(self):
    self.head = None
    self.size = 0


  def append(self, new_data):
    new_node = Node()
    new_node.data=new_data

    if self.head is None:
      self.head = new_node
    else:
      current_node = self.head
      while current_node.next is not None:
        current_node = current_node.next
      current_node.next = new_node
    self.size += 1


  def print_all(self):
    if self.head==None:
      print("List is empty")
    else:

      current_node = self.head
      while current_node!=None:
        print(current_node.data,end="-> ")
        current_node = current_node.next
      print()


  def addNodeBeforeValue(self, givenValue, newValue):
        new_node = Node()
        new_node.data = newValue

        if self.head is None:
            print("List is empty")
        elif self.head.data == givenValue:
            new_node.next = self.head
            self.head = new_node
        else:
            prev = self.head
            current = self.head

            while current is not None:
                if current.data == givenValue:
                    new_node.next = current
                    prev.next = new_node

                    return

                prev = current
                current = current.next

            print("Node not found")

myList = SinglyLinkedList()


print("Before add:")

myList.print_all()

myList.append(10)
myList.addNodeBeforeValue(10, 3)
myList.addNodeBeforeValue(10, 6)
myList.addNodeBeforeValue(10, 7)

print("After add:")
myList.print_all()
# Out:
# Before add:
# List is empty
# After add:
# 3-> 6-> 7-> 10->

# %% [markdown]
# #Problem 5.
#  Remove the even numbers from the following singly linked list. Write a utility function
# deleteeven(self) that will delete all even nodes from the singly linedlist
# ```bash
# 3->10->16->61->108->NULL
# ```
# ``` bash
# Fig A: List A
#
# 3->61->null
# ```

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class SinglyLinkedList:
  def __init__(self):
    self.head = None
    self.size = 0


  def append(self, new_data):
    new_node = Node(new_data)
    if self.head is None:
      self.head = new_node
    else:
      current_node = self.head
      while current_node.next is not None:
        current_node = current_node.next
      current_node.next = new_node
    self.size += 1


  def print_all(self):
    current_node = self.head
    while current_node!=None:
      print(current_node.data,end="-> ")
      current_node = current_node.next

    print("Null")

  def deleteeven(self):
    if self.head is None:
      print("List is empty")
    else:
      prev = self.head
      current = self.head
      next = self.head
      while current is not None:
        if current.data % 2 == 0:
          next = current.next
          prev.next = current.next
          current.next = None
          del current
          current = next
        else:
          prev = current
          current = current.next

myList = SinglyLinkedList()

myList.append(3)
myList.append(10)
myList.append(16)
myList.append(61)
myList.append(108)


print("Before deleteeven: ")
myList.print_all()
myList.deleteeven()
print("After deleteeven: ")
myList.print_all()
# Out:
# Before deleteeven:
# 3-> 10-> 16-> 61-> 108-> Null
# After deleteeven:
# 3-> 61-> Null

# %% [markdown]
# #Problem 6
# Write a utility function function named sorted_insert(self, v)  that takes a parameter v
# and inserts it into a singly linked list in ascending order. For example, if the list contains
# the following items:
#
# then, after calling sorted_insert(5), it will be as follows:
#
# ``` bash
# 3 -> 5 -> 6 -> 7-> 10 -> Null/ None
# ```
#
# ```bash
# class Node:
#   def __init__(self, d):
#     self.data = d
#     self.next = None
# class LinkedList:
#   def __init__(self):
#     self.head = None
#   def sorted_insert(self, v):
#     # write your code here
# sll = LinkedList()
# sll.sorted_insert(3)
# sll.sorted_insert(6)
# sll.sorted_insert(10)
# sll.sorted_insert(7)
# sll.sorted_insert(5)
# sll.display()
# ```

# %%
class Node:
  def __init__(self):
    self.data = 0
    self.next = None

class SinglyLinkedList:
  def __init__(self):
    self.head = None
    self.size = 0


  def append(self, new_data):
    new_node = Node(new_data)
    if self.head is None:
      self.head = new_node
    else:
      current_node = self.head
      while current_node.next is not None:
        current_node = current_node.next
      current_node.next = new_node
    self.size += 1


  def print_all(self):
    current_node = self.head
    while current_node!=None:
      print(current_node.data,end="-> ")
      current_node = current_node.next
    print("None")


  def search(self, data):
    current_node = self.head
    while current_node is not None:
      if current_node.data == data:
        return True
      current_node = current_node.next
    return False

  def sorted_insert(self, value):
    new_node =Node()
    new_node.data = value

    if self.head is None:
      self.head = new_node

    elif value <= self.head.data:
      new_node.next = self.head
      self.head = new_node

    else:
      old = self.head
      current = self.head.next

      while current is not None and current.data < value:
        old = current
        current = current.next
      old.next = new_node
      new_node.next = current


sll = SinglyLinkedList()
sll.sorted_insert(3)
sll.sorted_insert(6)
sll.sorted_insert(10)
sll.sorted_insert(7)
sll.sorted_insert(5)
sll.print_all()
# Out:
# 3-> 5-> 6-> 7-> 10-> None

# %% [markdown]
# #Problem 7.
# Assume there is a singly linked list. HEAD is the pointer for head node. Write a
# function reverseList(HEAD) to reverse the linked list. It means, the function will
# return the new head.
# Then print the reversed list.
#
# ``` bash
# Fig A : List A
# 3 -> 10 -> 17 -> 61 -> 107 -> Null
# ```
# Fter calling reverseList(A) it will return B such that
#
# ``` bash
# Fig B: List B
# 107 -> 61 -> 17 -> 10 -> 3 -> Null
# ```
# For example if 3 represents the head node in Fig A, it will represent the tail in Fig B.

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class SinglyLinkedList:
  def __init__(self):
    self.head = None
    self.size = 0


  def append(self, new_data):
    new_node = Node(new_data)
    if self.head is None:
      self.head = new_node
    else:
      current_node = self.head
      while current_node.next is not None:
        current_node = current_node.next
      current_node.next = new_node
    self.size += 1


  def print_all(self):
    current_node = self.head
    while current_node!=None:
      print(current_node.data,end="-> ")
      current_node = current_node.next
    print("None")


  def search(self, data):
    current_node = self.head
    while current_node is not None:
      if current_node.data == data:
        return True
      current_node = current_node.next
    return False

  def reverse_list(self):
    if self.head is None:
      print("List is empty")
    else:
      prev = None
      current = self.head
      next = None
      while current is not None:
        next = current.next
        current.next = prev
        prev = current
        current = next

      self.head = prev


myList = SinglyLinkedList()

myList.append(3)
myList.append(10)
myList.append(17)
myList.append(61)
myList.append(107)
myList.print_all()

myList.reverse_list()
myList.print_all()
# Out:
# 3-> 10-> 17-> 61-> 107-> None
# 107-> 61-> 17-> 10-> 3-> None

# %% [markdown]
# #Problem 8.
#  Assume, HEAD is the head-node of a doubly linked list (dll). Write a utility function
# addNodeAfterValue(self, givenValue, newValue) to insert a new value in this dll just
# after a given value.
#
# a. If the given value is found in the dll, insert the new value just after the given
# value.
#
# b. If the given value is not found, don’t add the node. Just print “Not found”

# %%
class Node:
  def __init__(self, data):
      self.data = data
      self.prev = None
      self.next = None

class DoublyLinkedList:
  def __init__(self):
    self.head = None
    self.tail = None
    self.size = 0

  def append(self, data):
    new_node = Node(data)

    if self.head is None:
      self.head = new_node
      self.tail = new_node
    else:
      self.tail.next = new_node
      new_node.prev = self.tail
      self.tail = new_node
    self.size += 1

  def delete(self, data):
    current = self.head
    while current is not None:
      if current.data == data:
        if current == self.head:
          self.head = current.next
          if current == self.tail:
            self.tail = None
          else:
            self.head.prev = None
        elif current == self.tail:
          current.prev.next = None
          self.tail = current.prev

        else:
          current.prev.next = current.next
          current.next.prev = current.prev

        self.size -= 1
        return
      current = current.next


  def print_all(self):
    print("List: ")
    current_node = self.head
    while current_node:
      print(current_node.data, end =" -> ")
      current_node = current_node.next
    print(None)

  def print_reverse(self):
    print("Reverse List: ")
    current_node = self.tail
    while current_node:
      print(current_node.data, end = "->")
      current_node = current_node.prev
    print()


  def search(self, data):
    current_node = self.head
    while current_node is not None:
      if current_node.data == data:
        return True
      current_node = current_node.next
    return False


  def clear(self):
    self.head = None
    self.tail = None


  def addNodeAfterValue(self, givenValue, newValue):
    if self.head is None:
      return

    current = self.head

    while current is not None and current.data != givenValue:
      current = current.next

    if current is None:
      print("Not found")
      return

    new_node = Node(newValue)

    new_node.prev = current
    new_node.next = current.next

    if current.next is not None:
        current.next.prev = new_node
    current.next = new_node




dll=DoublyLinkedList()

dll.append(2)
dll.append(55)
dll.append(6)
dll.append(9)

dll.print_all()
dll.addNodeAfterValue(6, 4)
dll.print_all()

dll.addNodeAfterValue(100, 4)
dll.print_all()
# Out:
# List:
# 2 -> 55 -> 6 -> 9 -> None
# List:
# 2 -> 55 -> 6 -> 4 -> 9 -> None
# Not found
# List:
# 2 -> 55 -> 6 -> 4 -> 9 -> None

# %% [markdown]
# #Problem 9.
# Given a sorted doubly linked list and a value to insert, write a function to insert the value in sorted way (and in efficient way). Initial doubly linked list.
# ```bash
# 3 <-> 5 <-> 8 <-> 10 <-> 12
# ```
# After calling insertSorted(9) the list will be as follows:
# ``` bash
# 3 <-> 5 <-> 8 <-> 9 <-> 10 <-> 12
# ```

# %%
class Node:
  def __init__(self, data):
      self.data = data
      self.prev = None
      self.next = None

class DoublyLinkedList:
  def __init__(self):
    self.head = None
    self.tail = None
    self.size = 0

  def append(self, data):
    new_node = Node(data)

    if self.head is None:
      self.head = new_node
      self.tail = new_node
    else:
      self.tail.next = new_node
      new_node.prev = self.tail
      self.tail = new_node
    self.size += 1

  def delete(self, data):
    current = self.head
    while current is not None:
      if current.data == data:
        if current == self.head:
          self.head = current.next

          if current == self.tail:
            self.tail = None
          else:
            self.head.prev = None
        elif current == self.tail:
          current.prev.next = None
          self.tail = current.prev

        else:
          current.prev.next = current.next
          current.next.prev = current.prev

        self.size -= 1
        return
      current = current.next


  def print_all(self):
    print("List: ")
    current_node = self.head
    while current_node:
      print(current_node.data, end =" -> ")
      current_node = current_node.next
    print("None")

  def print_reverse(self):
    print("Reverse List: ")
    current_node = self.tail
    while current_node:
      print(current_node.data, end = "->")
      current_node = current_node.prev
    print("None")


  def search(self, data):
    current_node = self.head
    while current_node is not None:
      if current_node.data == data:
        return True
      current_node = current_node.next
    return False


  def clear(self):
    self.head = None
    self.tail = None


  def insertSorted(self, data):
      new_node = Node(data)
      if self.head is None:
          self.head = new_node

      elif data <= self.head.data:
          new_node.next = self.head
          self.head.prev = new_node
          self.head = new_node

      else:
          current = self.head
          while current.next is not None and current.next.data < data:
            current = current.next
          new_node.next = current.next
          new_node.prev = current
          if current.next is not None:
              current.next.prev = new_node
          current.next = new_node



dll = DoublyLinkedList()
dll.insertSorted(3)
dll.insertSorted(5)
dll.insertSorted(8)
dll.insertSorted(10)
dll.insertSorted(12)


dll.print_all()

dll.insertSorted(9)

dll.print_all()
# Out:
# List:
# 3 -> 5 -> 8 -> 10 -> 12 -> None
# List:
# 3 -> 5 -> 8 -> 9 -> 10 -> 12 -> None
